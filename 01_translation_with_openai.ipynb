# %%
import requests
import dotenv
import os
import pandas as pd
import json

dotenv.load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
# API endpoint
url = "https://api.openai.com/v1/chat/completions"
model = "gpt-3.5-turbo"
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}'
    }

# %%
def translate(prompt, text, url, model, headers):

    # Request headers
    headers = headers
    # Request data
    data = {
        # 'prompt': prompt,
        # 'max_tokens': 15000,  # Maximum number of tokens (words) to generate
        'model': model,
        'messages': [
            {
                "role": "system",
                "content": prompt
            },
            {
                "role": "user",
                "content": text
            }
        ],
    }

    # Making the API request
    response = requests.post(url, headers=headers, json=data)

    # Check if the request was successful
    if response.status_code == 200:
        translated_text = response.json()['choices'][0]['message']['content']
    else:
        # Print error message
        print(f"Error: {response.status_code} - {response.text}")
    return translated_text

# %%
# creating a list of prompts

prompt1 = 'You are an expert translator. Translate the following text to Russian using vocabulary and expressions of a Russian native. The text to be translated is:'
prompt2 = 'You are an expert translator that will be tasked with translating a piece of text into Russian. The translation must be faithful to the original tone of voice and writing style. Ensure that the meaning of the original text is not changed. The text to be translated is:'
prompts = [prompt1, prompt2]

# %%
# reading a dataset of english texts and their human translations from various fields

df = pd.read_json('texts.json')
print(df.field.unique())
df
# Out:
# ['literature' 'medical' 'law']
#         field                                              title  \
# 0  literature               Of Human Bondage by Somerset Maugham
# 1  literature            A Tale of Two Cities by Charles Dickens
# 2     medical  Barnard C.N. The operation. A human cardiac tr...
# 3     medical  Guidelines on diabetes, pre-diabetes, and card...
# 4         law               CODE OF CONDUCT FOR EUROPEAN LAWYERS
# 5         law                The Indian Contract Act (ICA), 1872
#
#                                              en_text  \
# 0  The day broke gray and dull. The clouds hung h...
# 1  It was the best of times, it was the worst of ...
# 2  POSTOPERATIVE CARE. The postoperative care of ...
# 3  Definition and classification of diabetes. Cri...
# 4  1. PREAMBLE. 1.1. The Function of the Lawyer i...
# 5  Preamble. WHEREAS it is expedient to define an...
#
#                                 ru_human_translation
# 0  День занялся тусклый, серый. Тучи повисли низк...
# 1   Это было лучшее из всех времен, это было худш...
# 2  Послеоперационное ведение. Послеоперационное в...
# 3  Определение и классификация диабета. Критерии ...
# 4  I. Преамбула. 1.1. Функция адвоката в обществе...
# 5  Преамбула. Принимая во внимание целесообразнос...

# %%
# creating a list of (field, title, en text, human translation, prompt) tuples

texts = list(df.en_text)
fields = list(df.field)
titles = list(df.title)
human_ru = list(df.ru_human_translation)
prompt_texts = []

for prompt in prompts:
    item = [(field, title, text, human, prompt) for field, title, text, human in zip(fields, titles, texts, human_ru)]
    prompt_texts.extend(item)

len(prompt_texts)
# Out:
# 12

# %%
# sending (prompt, text) pairs to the API and collecting translated results by adding it to the list of tuples

prompt_text_translations = []

for item in prompt_texts:
    translation = translate(item[4], item[2], url, model, headers)
    new_item = (*item, translation)
    prompt_text_translations.append(new_item)

# %%
# creating a dataframe with the results

df2 = pd.DataFrame(prompt_text_translations, columns=['field', 'title', 'en_text', 'ru_human_translation', 'prompt', 'ru_machine_translation'])
df2.head()
# Out:
#         field                                              title  \
# 0  literature               Of Human Bondage by Somerset Maugham
# 1  literature            A Tale of Two Cities by Charles Dickens
# 2     medical  Barnard C.N. The operation. A human cardiac tr...
# 3     medical  Guidelines on diabetes, pre-diabetes, and card...
# 4         law               CODE OF CONDUCT FOR EUROPEAN LAWYERS
#
#                                              en_text  \
# 0  The day broke gray and dull. The clouds hung h...
# 1  It was the best of times, it was the worst of ...
# 2  POSTOPERATIVE CARE. The postoperative care of ...
# 3  Definition and classification of diabetes. Cri...
# 4  1. PREAMBLE. 1.1. The Function of the Lawyer i...
#
#                                 ru_human_translation  \
# 0  День занялся тусклый, серый. Тучи повисли низк...
# 1   Это было лучшее из всех времен, это было худш...
# 2  Послеоперационное ведение. Послеоперационное в...
# 3  Определение и классификация диабета. Критерии ...
# 4  I. Преамбула. 1.1. Функция адвоката в обществе...
#
#                                               prompt  \
# 0  You are an expert translator. Translate the fo...
# 1  You are an expert translator. Translate the fo...
# 2  You are an expert translator. Translate the fo...
# 3  You are an expert translator. Translate the fo...
# 4  You are an expert translator. Translate the fo...
#
#                               ru_machine_translation
# 0  День начался серым и унылым. Облака висели низ...
# 1  Это были лучшие времена, это были худшие време...
# 2  ПОСЛЕОПЕРАЦИОННЫЙ УХОД. Послеоперационный уход...
# 3  Определение и классификация диабета. Критерии ...
# 4  1. ПРЕАМБУЛА. 1.1. Роль адвоката в обществе В ...

# %% [markdown]
# In a separate notebook, I tokenized the original and translated entries with nltk's .sent_tokenize() and then parsed them by sentense using pandas' .explode() method. After saving the result as a .csv, I aligned the corresponding lines manually. The "en_ru_eval.csv" file below is the manually aligned data.

# %%
en_ru_aligned = pd.read_csv('en_ru_eval.csv', encoding='utf-8')
en_ru_aligned.head()
# Out:
#         field                                 title  \
# 0  literature  Of Human Bondage by Somerset Maugham
# 1  literature  Of Human Bondage by Somerset Maugham
# 2  literature  Of Human Bondage by Somerset Maugham
# 3  literature  Of Human Bondage by Somerset Maugham
# 4  literature  Of Human Bondage by Somerset Maugham
#
#                                              en_text  \
# 0                       The day broke gray and dull.
# 1  The clouds hung heavily, and there was a rawne...
# 2  A woman servant came into a room in which a ch...
# 3  She glanced mechanically at the house opposite...
# 4                       “Wake up, Philip,” she said.
#
#                                 ru_human_translation  \
# 0                       День занялся тусклый, серый.
# 1  Тучи повисли низко, воздух был студеный – вот-...
# 2  В комнату, где спал ребенок, вошла служанка и ...
# 3  Она по привычке окинула взглядом фасад дома на...
# 4                  – Вставай, Фи́лип, – сказала она.
#
#                                               prompt  \
# 0  You are an expert translator. Translate the fo...
# 1  You are an expert translator. Translate the fo...
# 2  You are an expert translator. Translate the fo...
# 3  You are an expert translator. Translate the fo...
# 4  You are an expert translator. Translate the fo...
#
#                               ru_machine_translation
# 0                       День начался серым и унылым.
# 1  Тучи висели тяжело, и в воздухе чувствовалась ...
# 2  Служанка вошла в комнату, в которой ребенок сп...
# 3  Она механически взглянула на дом напротив, дом...
# 4               "Просыпайся, Филипп," - сказала она.

# %%
# creating a dictionary from the dataframe to store as .json

reference_candidate_dict = {}

for index, row in en_ru_aligned.iterrows():
    label = row['field']
    prompt = row['prompt']
    machine_translation = row['ru_machine_translation']
    human_translation = row['ru_human_translation']
    
    if label in reference_candidate_dict:
        if prompt in reference_candidate_dict[label]:
            reference_candidate_dict[label][prompt].append((human_translation, machine_translation))
        else:
            reference_candidate_dict[label][prompt] = [(human_translation, machine_translation)]
    else:
        reference_candidate_dict[label] = {prompt: [(human_translation, machine_translation)]}

display(reference_candidate_dict)
# Out:
# {'literature': {'You are an expert translator. Translate the following text to Russian using vocabulary and expressions of a Russian native. The text to be translated is:': [('День занялся тусклый, серый.',
#     'День начался серым и унылым.'),
#    ('Тучи повисли низко, воздух был студеный – вот-вот выпадет снег.',
#     'Тучи висели тяжело, и в воздухе чувствовалась сырость, предвещавшая снег.'),
#    ('В комнату, где спал ребенок, вошла служанка и раздвинула шторы.',
#     'Служанка вошла в комнату, в которой ребенок спал, и открыла занавески.'),
#    ('Она по привычке окинула взглядом фасад дома напротив – оштукатуренный, с портиком – и подошла к детской кроватке.',
#     'Она механически взглянула на дом напротив, дом с лепной отделкой и колоннадой, и направилась к кровати ребенка.'),
#    ('– Вставай, Фи́лип, – сказала она.',
#     '"Просыпайся, Филипп," - сказала она.'),
#    ('Откинув одеяло, она взяла его на руки и снесла вниз.',
#     'Отвалила одеяло, взяла его на руки и понесла вниз.'),
#    ('Он еще не совсем проснулся.',
#     'Ребенок был только наполовину проснувшийся.'),
#    ('– Тебя зовет мама.', '"Твоя мама тебя ждет," - сказала она.'),
#    ('Отворив дверь в комнату на первом этаже, няня поднесла ребенка к постели, на которой лежала женщина.',
#     'Она открыла дверь комнаты на этаже ниже и отнесла ребенка к кровати, на которой лежала женщина.'),
#    ('Это была его мать.', 'Это была его мама.'),
#    ('Она протянула к мальчику руки, и он свернулся калачиком рядом с ней, не спрашивая, почему его разбудили.',
#     'Она протянула руки, и ребенок устроился у ее бока. Он не спрашивал, почему его разбудили.'),
#    ('Женщина поцеловала его зажмуренные глаза и худенькими руками ощупала теплое тельце сквозь белую фланелевую ночную рубашку.',
#     'Женщина поцеловала его глаза и тонкими руками ощупала теплое тело сквозь его белую фланелевую ночнушку.'),
#    ('Она прижала ребенка к себе.', 'Она прижала его покрепче к себе.'),
#    ('– Тебе хочется спать, детка? – спросила она.',
#     '"Ты хочешь поспать, дорогой?" - сказала она.'),
#    ('Голос у нее был такой слабый, что, казалось, он доносится откуда-то издалека.',
#     'Ее голос был настолько слабым, что казалось, будто он уже доносился издалека.'),
#    ('Мальчик не ответил и только сладко потянулся.',
#     'Ребенок не ответил, а просто улыбнулся удобно.'),
#    ('Ему было хорошо в теплой, просторной постели, в нежных объятиях.',
#     'Ему было очень уютно в большой, теплой постели, с этими мягкими руками вокруг.'),
#    ('Он попробовал стать еще меньше, сжался в комочек и сквозь сон ее поцеловал.',
#     'Он попытался сделаться еще меньше, прижимаясь к маме, и сонно поцеловал ее.'),
#    ('Глаза его закрылись, и он крепко уснул.',
#     'Через мгновение он закрыл глаза и заснул.'),
#    ('Доктор молча подошел к постели.',
#     'Доктор приблизился и остановился у кровати.'),
#    ('– Дайте ему побыть со мной хоть немножко, – простонала она.',
#     '"О, пока еще не уносите его," - стонала она.'),
#    ('Доктор не ответил и только строго на нее поглядел.',
#     'Доктор, не отвечая, серьезно посмотрел на нее.'),
#    ('Зная, что ей не позволят оставить ребенка, женщина поцеловала его еще раз, провела рукой по его телу; взяв правую ножку, она перебрала все пять пальчиков, а потом нехотя притронулась к левой ноге.',
#     'Зная, что ей не разрешат задерживать ребенка еще надолго, женщина поцеловала его снова, и протянула руку вдоль его тела до его ног; она взяла в руку правую ногу и почувствовала пять маленьких пальчиков; а затем медленно проскользнула своей рукой на левую ногу.'),
#    ('Она заплакала.', 'Она всхлипнула.'),
#    ('– Что с вами? – спросил врач.', '"Что случилось?" - спросил доктор.'),
#    ('– Вы устали.', '"Ты устала."'),
#    ('Она покачала головой, и слезы покатились у нее по щекам.',
#     'Она покачала головой, не в состоянии говорить, и слезы катились по ее щекам.'),
#    ('Доктор наклонился к ней.', 'Доктор склонился.'),
#    ('– Дайте его мне.', '"Позвольте мне взять его."'),
#    ('Она была слишком слаба, чтобы запротестовать.',
#     'Она была слишком слабой, чтобы противиться его желанию, и она отдала ребенка.'),
#    ('Врач передал ребенка на руки няньке.', 'Доктор вернул его няне.'),
#    ('– Положите его обратно в постельку.',
#     '"Лучше верните его обратно в его кровать."'),
#    ('– Сейчас.', '"Хорошо, сэр."'),
#    ('Спящего мальчика унесли.', 'Мальчик, все еще спящий, унесли.'),
#    ('Мать рыдала, уже не сдерживаясь.', 'Его мама теперь заплакала отчаянно.'),
#    ('– Бедняжка! Что с ним теперь будет!',
#     '"Что с ним будет, бедный ребенок?"'),
#    ('Сиделка пробовала ее успокоить; выбившись из сил, женщина перестала плакать.',
#     'Медсестра попыталась успокоить ее, и вскоре, изнемогая, плач прекратился.'),
#    ('Доктор подошел к столу в другом конце комнаты, где лежал прикрытый салфеткой труп новорожденного младенца.',
#     'Доктор подошел к столу по другую сторону комнаты, на котором, под полотенцем, лежало тело мертворожденного ребенка.'),
#    ('Приподняв салфетку, врач поглядел на безжизненное тельце.',
#     'Он поднял полотенце и посмотрел.'),
#    ('И, хотя кровать была отгорожена ширмой, женщина догадалась, что он делает.',
#     'Он был скрыт от кровати экраном, но женщина догадалась, что он делает.'),
#    ('– Мальчик или девочка? – шепотом спросила она у сиделки.',
#     '"Это был мальчик или девочка?" - шепнула она медсестре.'),
#    ('– Тоже мальчик.', '"Еще один мальчик."'),
#    ('Женщина ничего не сказала.', 'Женщина не ответила.'),
#    ('В комнату вернулась нянька.',
#     'В мгновение ока к ней вернулась няня ребенка.'),
#    ('Она подошла к больной.', 'Она приблизилась к кровати.'),
#    ('– Филип так и не проснулся, – сказала она.',
#     '"Мастер Филипп так и не проснулся," - сказала она.'),
#    ('Воцарилось молчание.', 'Пауза.'),
#    ('Доктор снова пощупал у больной пульс.',
#     'Затем врач снова ощупал пульс пациента.'),
#    ('– Пожалуй, пока я здесь больше не нужен, – сказал он.',
#     '"Мне кажется, пока я ничего не могу сделать," - сказал он.'),
#    ('– Зайду после завтрака.', '"Я приду еще после завтрака."'),
#    ('– Я вас провожу, – предложила сиделка.',
#     '"Позвольте вас проводить, сэр," - сказала няня ребенка.'),
#    ('Они молча спустились по лестнице в переднюю.',
#     'Они молча спустились вниз.'),
#    ('Доктор остановился.', 'В прихожей врач остановился.'),
#    ('– Вы послали за деверем миссис Кэри?', '"Вы вызвали брата миссис Кэри?'),
#    ('– Да.', '"Да, сэр."'),
#    ('– Как вы думаете, когда он приедет?',
#     '"Знаете, во сколько он будет здесь?"'),
#    ('– Не знаю, я жду телеграмму.', '- "Нет, сэр, я жду телеграмму."'),
#    ('– А что делать с мальчиком?', '"А что делать с мальчиком?'),
#    ('Не лучше ли его куда-нибудь пока отослать?',
#     'Мне кажется, ему будет лучше, если его убрать подальше."'),
#    ('– Мисс Уоткин согласилась взять его к себе.',
#     '"Мисс Уоткин сказала, что она его возьмет, сэр."'),
#    ('– А кто она такая?', '"Кто это?"'),
#    ('– Его крестная.', '- "Она его крестная мать, сэр.'),
#    ('Как по-вашему, миссис Кэри поправится?',
#     'Вы думаете, миссис Кэри поправится, сэр?"'),
#    ('Доктор покачал головой.', '- Врач покачал головой.'),
#    ('Неделю спустя Филип сидел на полу гостиной мисс Уоткин в Онслоу Гарденс.',
#     'Прошла неделя. Филипп сидел на полу в гостиной в доме мисс Уоткин на Онслоу-гарденс.'),
#    ('Он рос единственным ребенком в семье и привык играть один.',
#     'Был он единственным ребенком и привык заниматься сам.'),
#    ('Комната была заставлена громоздкой мебелью, и на каждой оттоманке лежало по три больших пуфа.',
#     'Комната была заполнена массивной мебелью, на каждом диване было три больших подушки.'),
#    ('В креслах тоже лежали подушки.', 'В каждом кресле тоже была подушка.'),
#    ('Филип стащил их на пол и, сдвинув легкие золоченые парадные стулья, построил затейливую пещеру, где мог прятаться от притаившихся за портьерами краснокожих.',
#     'Все они хватил и, с помощью легких и удобных для передвижения золоченых стульев, сделал сложную пещеру, в которой мог спрятаться от краснокожих индейцев, скрывающихся за занавесками.'),
#    ('Приложив ухо к полу, он прислушивался к дальнему топоту стада бизонов, несущихся по прерии.',
#     'Он прижал ухо к полу и слушал стадо буйволов, мчащихся по прерии.'),
#    ('Дверь отворилась, и он затаил дыхание, чтобы его не нашли, но сердитые руки отодвинули стул, и подушки повалились на пол.',
#     'Вдруг услышав открывающуюся дверь, он затаил дыхание, чтобы его не обнаружили; но резкая рука отодвинула стул, и подушки упали.'),
#    ('– Ах ты, шалун! Мисс Уоткин рассердится.',
#     '"Ты непослушный мальчик, мисс Уоткин будет сердита на тебя."'),
#    ('– Ку-ку, Эмма! – сказал он.', '"Привет, Эмма!" - сказал он.'),
#    ('Няня наклонилась, поцеловала его, а потом стала отряхивать и убирать подушки.',
#     'Няня наклонилась и поцеловала его, затем начала встряхивать подушки и расставлять их на место.'),
#    ('– Мы домой поедем? – спросил он.',
#     '"Мне приходить домой?" - спросил он.'),
#    ('– Да, я пришла за тобой.', '"Да, я пришла тебя забирать."'),
#    ('– У тебя новое платье.', '"Ты в новом платье."'),
#    ('Шел 1885 год, и женщины подкладывали под юбки турнюры.',
#     'Было восемнадцать восемьдесят пятый год, и ее платье было с выпуклостью.'),
#    ('Платье было сшито из черного бархата, с узкими рукавами и покатыми плечами; юбку украшали три широкие оборки.',
#     'Ее платье было из черного бархата, с узкими рукавами и низкими плечами, и юбка имела три больших оборки.'),
#    ('Капор тоже был черный и завязывался бархотками.',
#     'Она носила черный бонет с бархатными лентами.'),
#    ('Няня не знала, как ей быть.', 'Она колебалась.'),
#    ('Вопрос, которого она ждала, не был задан, и ей не на что было дать заранее приготовленный ответ.',
#     'Вопрос, который она ожидала, не последовал, и поэтому она не могла дать подготовленный ответ.'),
#    ('– Почему же ты не спрашиваешь, как поживает твоя мама? – не выдержала она наконец.',
#     '"Ты не спрашиваешь, как у твоей мамы?" - сказала она наконец.'),
#    ('– Я позабыл.', '"О, я забыл.'),
#    ('А как поживает мама?', 'Как у мамы?"'),
#    ('Теперь уже она могла ответить: – Твоей маме хорошо. Она очень счастлива.',
#     'Теперь она была готова. "Твоя мама совершенно здорова и счастлива."'),
#    ('– Да?', '"О, я рад."'),
#    ('– Мама уехала.', '"Твоя мама ушла.'),
#    ('Ты ее больше не увидишь.', 'Ты больше никогда её не увидишь."'),
#    ('Филип ничего не понимал.', 'Филипп не понял, что она имела в виду.'),
#    ('– Почему?', '"Почему?"'),
#    ('– Твоя мама на небе.', '- "Твоя мама в раю."'),
#    ('Она заплакала, и Филип, хоть и не знал, в чем дело, заплакал тоже.',
#     'Она начала плакать, и Филипп, хоть и не до конца понимал, тоже заплакал.'),
#    ('Эмма – высокая костистая женщина со светлыми волосами и грубоватыми чертами лица – была родом из Девоншира и, несмотря на многолетнюю службу в Лондоне, так и не отучилась от своего резкого говора.',
#     'Эмма была высокой, крупной женщиной, с светлыми волосами и крупными чертами лица. Она была из Девоншира и, несмотря на многолетнюю службу в Лондоне, никогда не потеряла своего акцента.'),
#    ('От слез она совсем растрогалась и крепко прижала мальчика к груди.',
#     'Ее слезы только усилили ее эмоции, и она прижала мальчика к своему сердцу.'),
#    ('Она понимала, какая беда постигла ребенка, лишенного той единственной любви, в которой не было и тени корысти.',
#     'Ей втуманилось, что ужасно, что ребенок лишается единственной на свете любви, которая абсолютно бескорыстна.'),
#    ('Ей казалось ужасным, что он попадет к чужим людям.',
#     'Ей показалось ужасным, что ему придется отдать его незнакомцам.'),
#    ('Но немного погодя она взяла себя в руки.',
#     'Но через некоторое время она взяла себя в руки.'),
#    ('– Тебя дожидается дядя Уильям, – сказала она. – Сходи попрощайся с мисс Уоткин, и мы поедем домой.',
#     '"Твой дядя Уильям ждет тебя, пойдем попрощаемся с мисс Уоткин, и мы поедем домой."'),
#    ('– Я не хочу с ней прощаться, – ответил он, почему-то стыдясь своих слез.',
#     '"Я не хочу прощаться," - ответил он, инстинктивно желая скрыть свои слезы.'),
#    ('– Ну ладно, тогда сбегай наверх и надень шляпу.',
#     '"Хорошо, побежи вверх и возьми свою шляпу."'),
#    ('Он принес шляпу. Эмма ждала его в прихожей.',
#     'Он взял ее, и когда спустился, Эмма ждала его в прихожей.'),
#    ('Из кабинета позади гостиной доносились голоса.',
#     'Он услышал звуки разговора в кабинете за столовой.'),
#    ('Филип в нерешительности остановился.', 'Он остановился.'),
#    ('Он знал, что мисс Уоткин и ее сестра разговаривают с приятельницами, и подумал – мальчику было всего девять лет, – что, если он к ним зайдет, они его пожалеют.',
#     'Он знал, что мисс Уоткин и ее сестра разговаривают с друзьями, и ему показалось — ему было девять лет — что если он войдет, они почувствуют к нему жалость.'),
#    ('– Я все-таки пойду попрощаюсь с мисс Уоткин.',
#     '"Думаю, я пойду попрощаюсь с мисс Уоткин."'),
#    ('– Вот молодец, сходи, – похвалила его Эмма.',
#     '"Тебе лучше, — сказала Эмма.'),
#    ('– Ты сперва им скажи, что я сейчас приду.',
#     '— Зайди и скажи, что я иду."'),
#    ('Ему хотелось получше обставить прощание.',
#     'Он хотел воспользоваться возможностью.'),
#    ('Эмма постучала в дверь и вошла.', 'Эмма постучала в дверь и вошла.'),
#    ('Он услышал, как она говорит: – Филип хочет с вами проститься.',
#     'Он услышал, как она говорила: "Мастер Филипп хочет попрощаться с вами, мисс."'),
#    ('Разговор сразу смолк, и Филип, прихрамывая, вошел в кабинет.',
#     'В разговоре внезапно встала тишина, и Филипп вошел.'),
#    ('Генриетта Уоткин была краснолицая, тучная дама с крашеными волосами.',
#     'Генриетта Уоткин была полной женщиной с красным лицом и окрашенными волосами.'),
#    ('В те дни крашеные волосы были редкостью и привлекали всеобщее внимание; Филип слышал немало пересудов на этот счет у себя дома, когда крестная вдруг изменила свою окраску.',
#     'В те дни окраска волос вызывала комментарии, и Филипп слышал много сплетен о том, когда окрасили волосы его крестной.'),
#    ('Жила она вдвоем со старшей сестрой, которая безропотно смирилась со своими преклонными годами.',
#     'Она жила с старшей сестрой, которая смирилась с преклонным возрастом.'),
#    ('В гостях у них были две незнакомые Филипу дамы; они с любопытством разглядывали мальчика.',
#     'Две женщины, которых Филипп не знал, пришли в гости, и они с любопытством посмотрели на него.'),
#    ('– Бедное мое дитя, – произнесла мисс Уоткин и широко раскрыла Филипу объятия.',
#     '"Мой бедный малыш," - сказала мисс Уоткин, разводя руки.'),
#    ('Она заплакала.', 'Она начала плакать.'),
#    ('Филип понял, почему она не вышла к обеду и надела черное платье.',
#     'Филипп теперь понял, почему ее не было на ланче и почему она была одета в черное.'),
#    ('Ей было трудно говорить.', 'Она не могла говорить.'),
#    ('– Мне надо домой, – прервал наконец молчание мальчик.',
#     '"Мне пора домой," - сказал Филипп, наконец.'),
#    ('Он высвободился из объятий мисс Уоткин, и она поцеловала его на прощание.',
#     'Он освободился из объятий мисс Уоткин, и она поцеловала его снова.'),
#    ('Потом Филип подошел к ее сестре и простился с ней.',
#     'Затем он подошел к ее сестре и тоже попрощался.'),
#    ('Одна из незнакомых дам спросила, можно ли ей тоже его поцеловать, и он степенно разрешил.',
#     'Одна из незнакомок попросила ее поцеловать его, и он серьезно дал ей на это разрешение.'),
#    ('У него хоть и текли слезы, но ему очень нравилось, что он причина такого переполоха; он с удовольствием побыл бы еще, чтобы его опять приласкали, но почувствовал, что мешает, и сказал, что Эмма, наверно, его дожидается.',
#     'Хоть он и плакал, но с острым удовольствием воспринял замечание, которое он произвел; он был бы рад остаться еще немного, чтобы его потешить, но чувствовал, что его ждут уходить, поэтому сказал, что Эмма ждет его.'),
#    ('Мальчик вышел из комнаты.', 'Он вышел из комнаты.'),
#    ('Эмма спустилась в помещение для прислуги поговорить со своей знакомой, и он остался ждать ее на площадке.',
#     'Эмма спустилась вниз, чтобы поговорить с подругой на застекленной веранде, и он ждал ее наверху.'),
#    ('До него донесся голос Генриетты Уоткин: – Его мать была моей самой близкой подругой.',
#     'Он услышал голос Генриетты Уоткин. "Его мама была моей лучшей подругой.'),
#    ('Никак не могу примириться с мыслью, что она умерла.',
#     'Я не могу перенести, что ее нет."'),
#    ('– Не надо было тебе ходить на похороны, Генриетта! – сказала сестра.',
#     '"Ты не должна была идти на похороны, Генриетта," - сказала ей ее сестра.'),
#    ('– Я так и знала, что ты вконец расстроишься.',
#     '- "Знала, что это тебя потрясет."'),
#    ('В беседу вмешалась одна из незнакомых дам: – Бедный малыш! Остался круглым сиротой – вот ужас!',
#     'Тогда одна из незнакомок заговорила. "Бедный маленький мальчик, ужасно думать о том, что он совсем один в этом мире.'),
#    ('Он, кажется, еще и хромой? – Да, от рождения.',
#     'Видимо, он хромает." "Да, у него косолапость.'),
#    ('Бедная мать так всегда горевала!',
#     'Он так тяжело переносил потерю его матери."'),
#    ('Пришла Эмма.', 'Тогда вернулась Эмма.'),
#    ('Они сели на извозчика, и Эмма сказала кучеру, куда ехать.',
#     'Они вызвали кэб, и она сказала водителю, куда ехать.'),
#    (' Это было лучшее из всех времен, это было худшее из всех времен; это был век мудрости, это был век глупости; это была эпоха веры, это была эпоха безверия; это были годы света, это были годы мрака; это была весна надежд, это была зима отчаяния; у нас было все впереди, у нас не было ничего впереди; все мы стремительно мчались в рай, все мы стремительно мчались в ад, - словом, то время было так похоже на наше, что наиболее крикливые его представители требовали, чтобы к нему применялась и в дурном и хорошем лишь превосходная степень сравнения.',
#     'Было лучшее время, было худшее время, был век мудрости, был век глупости, была эпоха веры, была эпоха недоверия, было время Света, было время Тьмы, это была весна надежды, это была зима отчаяния, у нас было все перед нами, у нас не было ничего перед нами, мы все шли прямо на небеса, мы все шли прямо в другую сторону - короче говоря, период был настолько похож на настоящий период, что некоторые из его самых шумных авторитетов настаивали на том, чтобы его воспринимали, хорошо или плохо, только в превосходной степени сравнения.'),
#    ('На английском престоле восседал король с широкой челюстью и королева с некрасивым лицом; на французском престоле восседал король с широкой челюстью и королева с красивым лицом.',
#     'В Англии был король с широкой челюстью и королева с простым лицом на троне; во Франции был король с широкой челюстью и королева с красивым лицом на троне.'),
#    ('В обоих государствах вельможи и лорды, обладатели благ земных, были твердо убеждены, что все благополучно и прочно установлено раз и навсегда.',
#     'В обоих странах было ясно, как хрусталь, для лордов Государственных запасов хлеба и рыбы, что все было окончательно утверждено.'),
#    ('То было лето от Рождества Христова тысяча семьсот семьдесят пятое.',
#     'Это был год нашего Господа одна тысяча семьсот семьдесят пятого.'),
#    ('И в ту благополучную эпоху, так же как и в нынешнюю, Англии были ниспосланы особые откровения свыше.',
#     'Духовные откровения были даны Англии в то благоприятное время, как и сейчас.'),
#    ('Миссис Соускотт только что отпраздновала двадцать пятый день своего благословенного рождения, хотя некий пророк из солдат лейб-гвардии предсказал, что все уже готово для того, чтобы в этот самый день Лондон и Вестминстер провалились сквозь землю.',
#     'Миссис Сауткотт недавно отметила свое двадцать пятое благословенное день рождение, о котором пророческий солдат из Лайф-гвардии предвкушал величественный вид, объявив, что были сделаны предприятия для поглощения Лондона и Уэстминстера.'),
#    ('Призрак, появлявшийся на улице Коклейн, всего только лет двенадцать как был укрощен, простучав все, что имел сообщить человечеству, совершенно так же, как в прошлом году новоявленные духи выстукивали свои сообщения, - мимоходом сказать, доказав этим сверхъестественное отсутствие всякой оригинальности.',
#     'Даже призрак улицы Кок-лейн был усмирен всего несколько лет назад, после того как выбивал свои послания, как духи этого прошедшего года (превосходно лишенные оригинальности) выбивали свои.'),
#    ('Другие сообщения - уже не столь сверхъестественным образом - начали с некоторых пор приходить по адресу английского народа и английских властей от конгресса британских подданных, находившихся в Америке; и, как это ни странно, эти сообщения оказались несравненно более важными для человечества, нежели все, что до сих пор человечеству приходилось выслушивать от духов и призраков, коклейнских и иных.',
#     'Просто послания в земном порядке событий недавно пришли к английской короне и народу от конгресса британских подданных в Америке, что, странно, оказались более важными для человечества, чем любые полученные до сих пор сообщения от курочек рода Кок-Лейн.'),
#    ('Франция, по части спиритических откровений вообще менее взысканная Небесами, чем ее заморская сестра, полегоньку катилась себе под гору, фабрикуя бумажные деньги и транжиря их.',
#     'Франция, менее благополучная в целом в духовном плане, чем ее сестра с щитом и трезубцем, скатывалась вниз с чрезвычайной плавностью, печатая бумажные деньги и тратя их.'),
#    ('Под руководством христианских своих пастырей забавлялась она, между прочим, и такими гуманными развлечениями: приговаривала юношу к отсечению обеих рук, вырыванию языка клещами и сожжению туловища живьем за то, что он не встал на колени - в грязи, под дождем, - в то время как на расстоянии пятидесяти или шестидесяти шагов от него проходила процессия монахов.',
#     'Под руководством своих христианских пастырей она развлекалась, кроме того, такими гуманными достижениями, как приговорить молодого человека к обезглавливанию, вырвать ему язык щипцами, и сжечь его живьем, потому что он не опустился на колени под дождем, чтобы почтить грязный процессионный шествие монахов, проходившее перед его глазами на расстоянии от пятидесяти до шестидесяти ярдов.'),
#    ('Очень вероятно, что в ту пору, когда казнили этого страдальца, где-нибудь в лесах Франции или Норвегии росли те самые деревья, уже отмеченные Дровосеком-Судьбой, деревья, из которых потом вырежут бревна, напилят доски и построят некую переносную машину с падающим ножом, столь страшную в истории человечества.',
#     'Вполне вероятно, что в коренных лесах Франции и Норвегии уже росли деревья, когда этого страдальца убили, их уже отметил Дровосек Судьба, чтоб их спилить и превратить в доски для изготовления определенной подвижной рамы с мешком и ножом, ужасной в истории.'),
#    ('Очень вероятно, что в тот самый день где-нибудь в сараях у земледельцев, обрабатывающих тяжелую почву ближайших окрестностей Парижа, стояли запрятанные от дождя грубые телеги, забрызганные деревенской грязью, и свиньи обнюхивали их, а куры несли в них яйца, а Хозяйка-Смерть уже отметила их для перевозки осужденных на казнь во время революции.',
#     'Вполне вероятно, что в грубых амбарах некоторых земледельцев, граничащих с Парижем, были укрыты от погоды в тот самый день примитивные телеги, окапанные деревенской грязью, зловонные от свиней и спящие в них птицы, которых Фермер Смерть уже отбросил для использования в его каретах революции.'),
#    ('Но и Дровосек, и Хозяйка хоть и работают беспрерывно, но работают тихо, и никто не слыхал, как бесшумной поступью они продвигались вперед; тем более что, если бы кто осмелился заявить об их приближении, того провозгласили бы безбожником и предателем.',
#     'Но тот Дровосек и тот Фермер, хотя они работали непрерывно, работали молча, и никто не слышал их, когда они передвигались шагами в одеждах: тем более, что даже подозревать, что они были бодры, было считаться безбожным и изменником.'),
#    ('В Англии тоже жилось не слишком безопасно и спокойно; оснований для национальной гордости было не много.',
#     'В Англии было едва ли достаточно порядка и защиты, чтобы оправдать многочисленные национальные самовосхваляния.'),
#    ('В самой столице каждую ночь совершались дерзкие грабежи, вооруженные люди врывались в дома, разбойники грабили по дорогам. Семейным людям официально рекомендовалось не иначе выезжать за город, как сдав свою городскую движимость на хранение в мебельные склады. Разбойник, выезжавший ночью на большую дорогу, днем мирно торговал в Сити; а когда его же собрат по торговле, на которого он нападал под видом капитана, узнавал его и называл по имени, капитан благороднейшим образом простреливал ему череп и уезжал. На почтовую карету однажды напало семеро; кондуктор троих уложил на месте, а остальные четверо уложили его самого, потому что у него не хватило зарядов,- после чего они преспокойно ограбили почту. Сам великолепный вельможа, лондонский лорд-мэр, ехавший через Тернгемский выгон, был остановлен одним разбойником, который без всякой церемонии обобрал высокопочтенного сановника в присутствии всей его свиты. В лондонских тюрьмах узники учиняли настоящие битвы со сторожами, а представители закона палили в них из мушкетов. Воры ухитрялись отрезывать бриллиантовые звезды с благородных лордов, являвшихся ко двору на торжественные приемы. Мушкетеры входили в церковь Сент-Джайлса в поисках контрабандных товаров, и при этом простой народ стрелял в мушкетеров, а мушкетеры стреляли в народ; и всем это казалось в порядке вещей.',
#     'Дерзкие грабежи вооруженными людьми и дорожные разбои происходили в самой столице каждую ночь; семьи открыто предупреждали не покидать город, не удалив свою мебель в магазины обитателей для безопасности; дорожник в темноте был городским торговцем на свете и, будучи узнанным и вызванным к действию своим собственным товарищем по торговле, которого он остановил как "Капитан", отважно выстрелил ему в голову и ускакал; почтовая карета была засадой семью разбойниками, и сторож выстрелил троих мертвых, а потом сам был застрелен оставшимися в живых четырьмя, "вследствие недостатка боеприпасов"; после чего почта была ограблена в мире; величественный правитель - лорд-мэр Лондона, был вынужден остановиться и сдать деньги на Тернхэм Грин, одним дорожным разбойником, который обокрал прославленного существа на виду у всего его окружения; заключенные в лондонских тюрьмах сражались с своими тюремщиками, и величие закона стреляло из ружей снарядами и шариками между ними; воры отрезали алмазные кресты с шеи благородных лордов на приемах в Королевских покоях; мушкетеры входили в Сент-Джайлс, чтобы искать контрабандные товары, и толпа стреляла по мушкетерам, а мушкетеры стреляли по толпе, и никто не считал эти события чем-то необычным.'),
#    ('И среди всей этой суеты без устали работал палач - работы у него было по горло, а дела не улучшались нисколько. Он был нарасхват: то вздернет гуртом целую гирлянду самых разнородных преступников, то повесит в субботу разбойника, пойманного не дальше как во вторник, то на площади у Ньюгетской тюрьмы сожжет десятки людей, то у ворот Вестминстера спалит пачку бумажных памфлетов; нынче казнит страшнейшего злодея и убийцу, а назавтра - жалкого воришку, стащившего шесть пенсов у мужика-батрака.',
#     'Во всем этом хаосе палач, всегда занятый и хуже чем бесполезный, был постоянно востребован; то повешивал длинные ряды разных преступников; то вешал грабителя в субботу, которого взяли во вторник; то сжигал людей в руку в Ньюгейте дюжинами, а то сжигал брошюры у дверей Вестминстерского зала; сегодня убивал чудовищного убийцу, завтра несчастного воришку, который обокрал крестьянского мальчика на шесть пенсов.'),
#    ('Все эти факты и тысячи им подобных происходили в благословенное лето от Рождества Христова тысяча семьсот семьдесят пятое, да и немного позже.',
#     'Все эти события и тысячи подобных им произошли в окружении и непосредственно после дорогого старого года одной тысячи семьсот семьдесят пятого.'),
#    ('В такой обстановке, пока таинственный Дровосек и Хозяйка действовали неслышно и невидимо, те двое с широкими челюстями и другие двое - одна с некрасивым, а другая с красивым лицом - шествовали своим путем довольно шумно, широко пользуясь своими божественными правами.',
#     'Окруженные ими, пока Дровосек и Фермер работали незамеченно, эти двое с широкими челюстями и те двое с простыми и красивыми лицами достаточно пешеходили и несли свои божественные права высокомерно.'),
#    ('Таким-то образом этот тысяча семьсот семьдесят пятый год вел предназначенными им дорогами как этих высоких особ, так и мириады всякой мелкоты, в том числе и тех мелких существ, о которых будет речь в этой летописи.',
#     'Так вели свою Величества год одна тысяча семьсот семьдесят пятого, и миллиарды мелких существ - существ этой хроники среди прочих - шли по дорогам, что лежали перед ними.')],
#   'You are an expert translator that will be tasked with translating a piece of text into Russian. The translation must be faithful to the original tone of voice and writing style. Ensure that the meaning of the original text is not changed. The text to be translated is:': [('День занялся тусклый, серый.',
#     'День настал серым и унылым.'),
#    ('Тучи повисли низко, воздух был студеный – вот-вот выпадет снег.',
#     'Облака висели низко, и в воздухе чувствовалась сырость, предвещавшая снег.'),
#    ('В комнату, где спал ребенок, вошла служанка и раздвинула шторы.',
#     'Женщина-служанка вошла в комнату, где спал ребенок, и отодвинула занавески.'),
#    ('Она по привычке окинула взглядом фасад дома напротив – оштукатуренный, с портиком – и подошла к детской кроватке.',
#     'Она механически посмотрела на дом напротив, с штукатурным фасадом и портиком, и подошла к кровати ребенка.'),
#    ('– Вставай, Фи́лип, – сказала она.', '"Просыпайся, Филипп," сказала она.'),
#    ('Откинув одеяло, она взяла его на руки и снесла вниз.',
#     'Скинув одеяло, она взяла его на руки и унесла вниз по лестнице.'),
#    ('Он еще не совсем проснулся.', 'Мальчик был только полусонный.'),
#    ('– Тебя зовет мама.', '"Тебя зовут мама," сказала она.'),
#    ('Отворив дверь в комнату на первом этаже, няня поднесла ребенка к постели, на которой лежала женщина.',
#     'Открыв дверь комнаты на этаже ниже, она отнесла ребенка к постели, на которой лежала женщина.'),
#    ('Это была его мать.', 'Это была его мать.'),
#    ('Она протянула к мальчику руки, и он свернулся калачиком рядом с ней, не спрашивая, почему его разбудили.',
#     'Она протянула руки, и ребенок устроился у ее бока. Он не спрашивал, почему его разбудили.'),
#    ('Женщина поцеловала его зажмуренные глаза и худенькими руками ощупала теплое тельце сквозь белую фланелевую ночную рубашку.',
#     'Женщина поцеловала его в глаза и своими тонкими, маленькими руками пощупала теплое тело сквозь его белую фланелевую пижаму.'),
#    ('Она прижала ребенка к себе.', 'Она прижала его поближе к себе.'),
#    ('– Тебе хочется спать, детка? – спросила она.',
#     '"Ты устал, дорогой?" - сказала она.'),
#    ('Голос у нее был такой слабый, что, казалось, он доносится откуда-то издалека.',
#     'Ее голос был таким слабым, словно он уже раздавался издалека.'),
#    ('Мальчик не ответил и только сладко потянулся.',
#     'Ребенок не ответил, но улыбнулся довольно.'),
#    ('Ему было хорошо в теплой, просторной постели, в нежных объятиях.',
#     'Ему было очень уютно в большой, теплой постели, с этими мягкими руками вокруг него.'),
#    ('Он попробовал стать еще меньше, сжался в комочек и сквозь сон ее поцеловал.',
#     'Он старался сделаться еще меньше, прижавшись к матери, и сонно поцеловал ее.'),
#    ('Глаза его закрылись, и он крепко уснул.',
#     'Вскоре он закрыл глаза и глубоко уснул.'),
#    ('Доктор молча подошел к постели.', 'Врач подошел к постели.'),
#    ('– Дайте ему побыть со мной хоть немножко, – простонала она.',
#     '"О, не забирайте его пока," - промямлила она.'),
#    ('Доктор не ответил и только строго на нее поглядел.',
#     'Врач, не ответив, взглянул на нее серьезно.'),
#    ('Зная, что ей не позволят оставить ребенка, женщина поцеловала его еще раз, провела рукой по его телу; взяв правую ножку, она перебрала все пять пальчиков, а потом нехотя притронулась к левой ноге.',
#     'Зная, что ей не разрешат держать ребенка долго, женщина поцеловала его снова; и она провела рукой по его телу до ног; она взяла правую ногу в руку и пощупала пять маленьких пальцев; потом медленно провела рукой по левой.'),
#    ('Она заплакала.', 'Она проплакала.'),
#    ('– Что с вами? – спросил врач.', '"В чем дело?" - спросил врач.'),
#    ('– Вы устали.', '"Ты устала."'),
#    ('Она покачала головой, и слезы покатились у нее по щекам.',
#     'Она покачала головой, не в силах говорить, и слезы катились по ее щекам.'),
#    ('Доктор наклонился к ней.', 'Врач наклонился.'),
#    ('– Дайте его мне.', '"Позвольте мне забрать его."'),
#    ('Она была слишком слаба, чтобы запротестовать.',
#     'Она была слишком слаба, чтобы сопротивляться его желанию, и она отпустила ребенка.'),
#    ('Врач передал ребенка на руки няньке.', 'Врач передал его няне.'),
#    ('– Положите его обратно в постельку.',
#     '"Лучше уложите его опять в его кровать."'),
#    ('– Сейчас.', '"Хорошо, сэр."'),
#    ('Спящего мальчика унесли.',
#     'Маленького мальчика, все еще спящего, унесли.'),
#    ('Мать рыдала, уже не сдерживаясь.',
#     'Его мама теперь рыдала от сокрушенности.'),
#    ('– Бедняжка! Что с ним теперь будет!',
#     '"Что будет с ним, бедный ребенок?"'),
#    ('Сиделка пробовала ее успокоить; выбившись из сил, женщина перестала плакать.',
#     'Медсестра попыталась успокоить ее, и вскоре, изнеможденная, плач прекратился.'),
#    ('Доктор подошел к столу в другом конце комнаты, где лежал прикрытый салфеткой труп новорожденного младенца.',
#     'Врач подошел к столу на другой стороне комнаты, под полотенцем лежало тело мертворожденного ребенка.'),
#    ('Приподняв салфетку, врач поглядел на безжизненное тельце.',
#     'Он поднял полотенце и посмотрел.'),
#    ('И, хотя кровать была отгорожена ширмой, женщина догадалась, что он делает.',
#     'Он был скрыт от кровати параваном, но женщина догадалась, что он делает.'),
#    ('– Мальчик или девочка? – шепотом спросила она у сиделки.',
#     '"Это был мальчик или девочка?" - шепнула она медсестре.'),
#    ('– Тоже мальчик.', '"Опять мальчик."'),
#    ('Женщина ничего не сказала.', 'Женщина не ответила.'),
#    ('В комнату вернулась нянька.', 'Вскоре вернулась няня ребенка.'),
#    ('Она подошла к больной.', 'Она приблизилась к постели.'),
#    ('– Филип так и не проснулся, – сказала она.',
#     '"Маленький Филипп так и не проснулся," - сказала она.'),
#    ('Воцарилось молчание.', 'Наступила пауза.'),
#    ('Доктор снова пощупал у больной пульс.',
#     'Затем врач снова проверил пульс пациентки.'),
#    ('– Пожалуй, пока я здесь больше не нужен, – сказал он.',
#     '"Сейчас мне кажется, мне нечего делать," - сказал он.'),
#    ('– Зайду после завтрака.', '- "Я заеду снова после завтрака."'),
#    ('– Я вас провожу, – предложила сиделка.',
#     '"Я провожу вас, сэр," - сказала няня ребенка.'),
#    ('Они молча спустились по лестнице в переднюю. Доктор остановился.',
#     'Они молча спустились вниз. В прихожей врач остановился.'),
#    ('– Вы послали за деверем миссис Кэри?',
#     '"Вы вызвали брата миссис Керри, не так ли?"'),
#    ('– Да.', '- "Да, сэр."'),
#    ('– Как вы думаете, когда он приедет?',
#     '- "Вы знаете, во сколько он придет?"'),
#    ('– Не знаю, я жду телеграмму.', '- "Нет, сэр, я жду телеграмму."'),
#    ('– А что делать с мальчиком?', '- "А с маленьким мальчиком что делать?'),
#    ('Не лучше ли его куда-нибудь пока отослать?',
#     'Наверное, лучше, чтобы его не было" '),
#    ('– Мисс Уоткин согласилась взять его к себе.',
#     '- "Мисс Уоткин сказала, что она его возьмет, сэр."'),
#    ('– А кто она такая?', '- "Кто это?"'),
#    ('– Его крестная.', '- "Она его крестная, сэр.'),
#    ('Как по-вашему, миссис Кэри поправится?',
#     'Вы думаете, что миссис Керри все переживет, сэр?"'),
#    ('Доктор покачал головой.', '- Врач покачал головой.'),
#    ('Неделю спустя Филип сидел на полу гостиной мисс Уоткин в Онслоу Гарденс.',
#     'Прошла неделя. Филипп сидел на полу в гостиной дома миссис Уоткин в Онслоу-гарденс.'),
#    ('Он рос единственным ребенком в семье и привык играть один.',
#     'Он был единственным ребенком и привык занимать себя сам.'),
#    ('Комната была заставлена громоздкой мебелью, и на каждой оттоманке лежало по три больших пуфа.',
#     'Комната была полна массивной мебели, и на каждом диване было три больших подушки.'),
#    ('В креслах тоже лежали подушки.', 'В каждом кресле тоже была подушка.'),
#    ('Филип стащил их на пол и, сдвинув легкие золоченые парадные стулья, построил затейливую пещеру, где мог прятаться от притаившихся за портьерами краснокожих.',
#     'Все они были захвачены им, и с помощью легких и удобных для перемещения золоченых кресел-рукавиц он устроил сложную пещеру, в которой мог спрятаться от краснокожих, скрывающихся за занавесками.'),
#    ('Приложив ухо к полу, он прислушивался к дальнему топоту стада бизонов, несущихся по прерии.',
#     'Он приставил ухо к полу и слушал, как бежит стадо бизонов по прерии.'),
#    ('Дверь отворилась, и он затаил дыхание, чтобы его не нашли, но сердитые руки отодвинули стул, и подушки повалились на пол.',
#     'Внезапно услышав, как открывается дверь, он затаил дыхание, чтобы его не обнаружили; но резкая рука отодвинула стул, и подушки упали.'),
#    ('– Ах ты, шалун! Мисс Уоткин рассердится.',
#     '"Непослушный мальчик, мисс Уоткин будет вам сердита."'),
#    ('– Ку-ку, Эмма! – сказал он.', '"Привет, Эмма!" - сказал он.'),
#    ('Няня наклонилась, поцеловала его, а потом стала отряхивать и убирать подушки.',
#     'Няня наклонилась и поцеловала его, затем принялась разглаживать подушки и ставить их на место.'),
#    ('– Мы домой поедем? – спросил он.',
#     '"Могу я вернуться домой?" - спросил он.'),
#    ('– Да, я пришла за тобой.', '"Да, я пришла за тобой."'),
#    ('– У тебя новое платье.', '- "Ты в новом платье."'),
#    ('Шел 1885 год, и женщины подкладывали под юбки турнюры.',
#     '- Сейчас был 1885 год, и она носила крылья.'),
#    ('Платье было сшито из черного бархата, с узкими рукавами и покатыми плечами; юбку украшали три широкие оборки.',
#     'Ее платье было из черного бархата, с узкими рукавами и наклонными плечами, а юбка имела три больших оборки.'),
#    ('Капор тоже был черный и завязывался бархотками.',
#     'На ней был черный тюль с бархатными лентами.'),
#    ('Няня не знала, как ей быть.', 'Она помедлила.'),
#    ('Вопрос, которого она ждала, не был задан, и ей не на что было дать заранее приготовленный ответ.',
#     'Вопрос, который она ожидала, не прозвучал, и поэтому она не могла дать подготовленный ответ.'),
#    ('– Почему же ты не спрашиваешь, как поживает твоя мама? – не выдержала она наконец.',
#     '"А ты не спросишь, как ваша мама?" - сказала она наконец.'),
#    ('– Я позабыл.', '- "О, я забыл.'),
#    ('А как поживает мама?', 'Как мама?"'),
#    ('Теперь уже она могла ответить: – Твоей маме хорошо. Она очень счастлива.',
#     'Сейчас она была готова. "Твоя мама совершенно здорова и счастлива."'),
#    ('– Да?', '- "О, как я рад."'),
#    ('– Мама уехала.', '- "Твоя мама ушла.'),
#    ('Ты ее больше не увидишь.', 'Ты больше никогда ее не увидишь."'),
#    ('Филип ничего не понимал.', 'Филипп не понял, что она имела в виду.'),
#    ('– Почему?', '"Почему?"'),
#    ('– Твоя мама на небе.', '- "Твоя мама в раю."'),
#    ('Она заплакала, и Филип, хоть и не знал, в чем дело, заплакал тоже.',
#     'Она начала плакать, и Филипп, хотя и не совсем понимал, тоже расплакался.'),
#    ('Эмма – высокая костистая женщина со светлыми волосами и грубоватыми чертами лица – была родом из Девоншира и, несмотря на многолетнюю службу в Лондоне, так и не отучилась от своего резкого говора.',
#     'Эмма была высокая, костистая женщина с светлыми волосами и крупными чертами лица. Она родом из Девоншира и, несмотря на многолетнюю службу в Лондоне, никогда не утратила своего диалекта.'),
#    ('От слез она совсем растрогалась и крепко прижала мальчика к груди.',
#     'Слезы усилили ее волнение, и она прижала мальчика к своему сердцу.'),
#    ('Она понимала, какая беда постигла ребенка, лишенного той единственной любви, в которой не было и тени корысти.',
#     'Она как-то неясно почувствовала жалость к тому ребенку, лишенному единственной в мире любви, которая совершенно бескорыстна.'),
#    ('Ей казалось ужасным, что он попадет к чужим людям.',
#     'Показалось ужасным, что ему придется оказаться в чужих руках.'),
#    ('Но немного погодя она взяла себя в руки.', 'Но вскоре она собрала себя.'),
#    ('– Тебя дожидается дядя Уильям, – сказала она. – Сходи попрощайся с мисс Уоткин, и мы поедем домой.',
#     '"Тебя ждет дядя Уильям, чтобы проводить тебя," - сказала она. - "Пойди и попрощайся с мисс Уоткин, и мы отправимся домой."'),
#    ('– Я не хочу с ней прощаться, – ответил он, почему-то стыдясь своих слез.',
#     '- "Мне не хочется прощаться," - ответил он, инстинктивно стремясь скрыть свои слезы.'),
#    ('– Ну ладно, тогда сбегай наверх и надень шляпу.',
#     '- "Хорошо, поднимись наверх и возьми шляпу."'),
#    ('Он принес шляпу. Эмма ждала его в прихожей.',
#     'Он взял ее, и когда спустился, Эмма ждала его в прихожей.'),
#    ('Из кабинета позади гостиной доносились голоса.',
#     'Он услышал звук голосов из кабинета за столовой.'),
#    ('Он знал, что мисс Уоткин и ее сестра разговаривают с приятельницами, и подумал – мальчику было всего девять лет, – что, если он к ним зайдет, они его пожалеют.',
#     'Он знал, что мисс Уоткин и ее сестра разговаривают с друзьями, и ему, ему девять лет, показалось, что если он войдет, они почувствуют сожаление к нему.'),
#    ('– Я все-таки пойду попрощаюсь с мисс Уоткин.',
#     '"Думаю, я пойду попрощаюсь с мисс Уоткин."'),
#    ('– Вот молодец, сходи, – похвалила его Эмма.',
#     '- "Пожалуй, тебе лучше," - сказала Эмма.'),
#    ('– Ты сперва им скажи, что я сейчас приду.',
#     '- "Зайди и скажи, что я иду," - сказал он.'),
#    ('Ему хотелось получше обставить прощание.',
#     'Он хотел использовать максимум своего шанса.'),
#    ('Эмма постучала в дверь и вошла.', 'Эмма постучала в дверь и вошла.'),
#    ('Он услышал, как она говорит: – Филип хочет с вами проститься.',
#     'Он услышал, как она говорит. "Мастер Филипп хочет попрощаться с вами, мисс."'),
#    ('Разговор сразу смолк, и Филип, прихрамывая, вошел в кабинет.',
#     'В разговоре внезапно наступила тишина, и Филипп зашатался в комнату.'),
#    ('Генриетта Уоткин была краснолицая, тучная дама с крашеными волосами.',
#     'Генриетта Уоткин была плотной женщиной с красным лицом и окрашенными волосами.'),
#    ('В те дни крашеные волосы были редкостью и привлекали всеобщее внимание; Филип слышал немало пересудов на этот счет у себя дома, когда крестная вдруг изменила свою окраску.',
#     'В те дни окрашивание волос вызывало разговоры, и Филипп много слышал на эту тему дома, когда рассказывали о перемене цвета волос его крестной.'),
#    ('Жила она вдвоем со старшей сестрой, которая безропотно смирилась со своими преклонными годами.',
#     'Она жила с старшей сестрой, которая спокойно примирилась с старостью.'),
#    ('В гостях у них были две незнакомые Филипу дамы; они с любопытством разглядывали мальчика.',
#     'Две леди, которых Филипп не знал, приехали в гости и с любопытством посмотрели на него.'),
#    ('– Бедное мое дитя, – произнесла мисс Уоткин и широко раскрыла Филипу объятия.',
#     '"Мой бедный мальчик," - сказала мисс Уоткин, раскрыв руки.'),
#    ('Она заплакала.', 'Она начала плакать.'),
#    ('Филип понял, почему она не вышла к обеду и надела черное платье.',
#     'Филипп теперь понял, почему ее не было на обеде и почему она была в черном платье.'),
#    ('Ей было трудно говорить.', 'Она не могла говорить.'),
#    ('– Мне надо домой, – прервал наконец молчание мальчик.',
#     '"Мне пора домой," - сказал Филипп наконец.'),
#    ('Он высвободился из объятий мисс Уоткин, и она поцеловала его на прощание.',
#     'Он выскользнул из объятий мисс Уоткин и она снова поцеловала его.'),
#    ('Потом Филип подошел к ее сестре и простился с ней.',
#     'Затем он подошел к ее сестре и попрощался с ней тоже.'),
#    ('Одна из незнакомых дам спросила, можно ли ей тоже его поцеловать, и он степенно разрешил.',
#     'Одна из незнакомых леди спросила, может ли поцеловать его, и он серьезно разрешил.'),
#    ('У него хоть и текли слезы, но ему очень нравилось, что он причина такого переполоха; он с удовольствием побыл бы еще, чтобы его опять приласкали, но почувствовал, что мешает, и сказал, что Эмма, наверно, его дожидается.',
#     'Несмотря на слезы, он остро наслаждался тем вниманием, которое он привлекал; ему было бы приятно остаться еще немного, чтобы его жаловали, но ему казалось, что его ждут, и поэтому он сказал, что Эмма ждет его.'),
#    ('Мальчик вышел из комнаты.', 'Он вышел из комнаты.'),
#    ('Эмма спустилась в помещение для прислуги поговорить со своей знакомой, и он остался ждать ее на площадке.',
#     'Эмма спустилась вниз, чтобы поговорить с подругой в подвале, и он подождал ее на лестничной площадке.'),
#    ('До него донесся голос Генриетты Уоткин: – Его мать была моей самой близкой подругой.',
#     'Он услышал голос Генриетты Уоткин. "Его мама была моей лучшей подругой.'),
#    ('Никак не могу примириться с мыслью, что она умерла.',
#     'Я не могу смириться с мыслью, что ее больше нет."'),
#    ('– Не надо было тебе ходить на похороны, Генриетта! – сказала сестра.',
#     '- "Тебе не стоило идти на похороны, Генриетта," - сказала ее сестра.'),
#    ('– Я так и знала, что ты вконец расстроишься.',
#     '- "Я знала, что это тебя расстроит."'),
#    ('В беседу вмешалась одна из незнакомых дам: – Бедный малыш! Остался круглым сиротой – вот ужас!',
#     'Затем заговорила одна из незнакомок. "Бедный маленький мальчик, ужасно думать о том, что он совершенно один в этом мире.'),
#    ('Он, кажется, еще и хромой? – Да, от рождения.',
#     'Я вижу, что он хромает." - "Да, у него косолапое.'),
#    ('Бедная мать так всегда горевала!',
#     'Это было такой горестью для его мамы."'),
#    ('Пришла Эмма.', 'Затем вернулась Эмма.'),
#    ('Они сели на извозчика, и Эмма сказала кучеру, куда ехать.',
#     'Они вызвали кэб, и она сказала водителю, куда нужно ехать.'),
#    (' Это было лучшее из всех времен, это было худшее из всех времен; это был век мудрости, это был век глупости; это была эпоха веры, это была эпоха безверия; это были годы света, это были годы мрака; это была весна надежд, это была зима отчаяния; у нас было все впереди, у нас не было ничего впереди; все мы стремительно мчались в рай, все мы стремительно мчались в ад, - словом, то время было так похоже на наше, что наиболее крикливые его представители требовали, чтобы к нему применялась и в дурном и хорошем лишь превосходная степень сравнения.',
#     'Были лучшие времена, были худшие времена, был век мудрости, был век глупости, была эпоха веры, было время неверия, было время Света, было время Тьмы, была весна надежды, была зима отчаяния, у нас было все перед нами, у нас не было ничего перед нами, мы все шли прямиком в рай, мы все шли прямиком в противоположном направлении - короче говоря, период тогда был настолько похож на настоящий период, что некоторые из его самых шумных авторитетов настаивали на том, чтобы он воспринимался, будь то в хорошем, будь то во зле, только в превосходной степени сравнения.'),
#    ('На английском престоле восседал король с широкой челюстью и королева с некрасивым лицом; на французском престоле восседал король с широкой челюстью и королева с красивым лицом.',
#     'В те времена на престоле Англии царствовали король с большой челюстью и королева с обычным лицом; на престоле Франции царствовали король с большой челюстью и королева с красивым лицом.'),
#    ('В обоих государствах вельможи и лорды, обладатели благ земных, были твердо убеждены, что все благополучно и прочно установлено раз и навсегда.',
#     'В обеих странах было ясно, как кристалл, для властителей Государства, хранящих запасы теста и рыбы, что в целом все было урегулировано навсегда.'),
#    ('То было лето от Рождества Христова тысяча семьсот семьдесят пятое.',
#     'Это был год нашего Господа тысяча семьсот семьдесят пятого.'),
#    ('И в ту благополучную эпоху, так же как и в нынешнюю, Англии были ниспосланы особые откровения свыше.',
# ...
#    ('Под понятием «международная деятельность» следует понимать: а) все профессиональные контакты с адвокатами государств-членов, кроме своего государствачлена; б) профессиональную деятельность адвоката одного из государств-членов в другом государстве-члене, независимо от его физического нахождения в этой стране.',
#     'Под пограничной деятельностью понимается: (a) все профессиональные контакты с адвокатами других государств-членов, отличных от государства адвоката; (b) профессиональная деятельность адвоката в государстве-члене, отличном от его или ее собственного, независимо от того, присутствует ли адвокат физически в этом государстве-члене.'),
#    ('Определения.', 'Определения.'),
#    ('В настоящем Кодексе принимаются следующие определения: «Государство-член» означает государство – член Европейского Союза или любое другое государство, чья адвокатская деятельность подпадает под статью 1.4.',
#     'В настоящем Кодексе: «Государство-член» означает государство-член Европейского Союза или любое другое государство, чья юридическая профессия включена в статью 1.4.'),
#    ('«Государство регистрации» означает государство-член, где адвокат приобрел право заниматься адвокатской деятельностью.',
#     '«Домашнее государство-член» означает государство-член, где адвокат получил право носить свое профессиональное звание.'),
#    ('«Государство нахождения» – любое другое государство Союза, где адвокат занимается профессиональной деятельностью.',
#     '«Принимающее государство-член» означает любое другое государство-член, где адвокат осуществляет пограничную деятельность.'),
#    ('«Компетентный орган» – профессиональная организация или полномочный орган одного из государств-членов, ответственные за установление правил профессионального поведения адвокатов и налагающие дисциплинарные взыскания.',
#     '«Компетентный орган» означает профессиональные организации или органы заинтересованные государства вопросами установления правил профессионального поведения и администрирования дисциплинарных дел адвокатов.'),
#    ('«Директива 77/249/ЕЭС» означает Директиву Совета 77/249/ЕЭС от 22 марта 1977 года о содействии эффективному осуществлению свободного предоставления услуг адвокатами.',
#     '«Директива 77/249/ЕЭП» – это Директива Совета 77/249/ЕЭП от 22 марта 1977 года, облегчающая эффективное осуществление адвокатом свободы оказания услуг.'),
#    ('«Директива 98/5/EC» означает Директиву 98/5/ЕС Европейского Парламента и Совета Европейского Союза от 16 февраля 1998 года об упрощении порядка осуществления на постоянной основе адвокатской деятельности в ином государстве-члене, нежели то, где была приобретена квалификация.',
#     '«Директива 98/5/ЕЭП» означает Директиву 98/5/ЕЭП Европейского Парламента и Совета от 16 февраля 1998 года облегчающую осуществление профессиональной деятельности адвоката постоянно в государстве-члене, не совпадающем с государством, в котором получена квалификация.'),
#    ('Общие правила положения.', 'ОБЩИЕ ПРИНЦИПЫ.'),
#    ('Независимость ', 'Независимость.'),
#    ('Многие задачи, выполняемые адвокатом в процессе профессиональной деятельности, требуют его абсолютной независимости и отсутствия какого-либо влияния на него, связанного, в первую очередь, с его личной заинтересованностью или с давлением извне.',
#     'Многочисленные обязанности, налагаемые на адвоката, требуют абсолютной независимости адвоката, свободной от любого влияния, особенно от такого, которое может возникнуть из его или ее личных интересов или внешнего давления.'),
#    ('Независимое положение адвоката способствует укреплению в обществе доверия к процедурам правосудия и беспристрастности судей.',
#     'Такая независимость необходима для доверия к процессу правосудия, как и нейтралитет судьи.'),
#    ('Таким образом, адвокату следует избегать каких-либо ущемлений собственной независимости и не поступаться принципами профессионального долга ради интересов клиента, суда или других лиц.',
#     'Поэтому адвокат должен избегать нарушения своей независимости и остерегаться компрометирования своих профессиональных стандартов, чтобы угодить клиенту, суду или третьим лицам.'),
#    ('Эта независимость также необходима как в вопросах бесспорного характера, так и в судебном разбирательстве.',
#     'Эта независимость необходима как в непроцессуальных вопросах, так и в судебных разбирательствах.'),
#    ('Совет, полученный клиентом от адвоката, теряет смысл, если последний дал его, руководствуясь соображениями собственной выгоды или из каких-либо других корыстных интересов, или под воздействием давления извне.',
#     'Совет, данней адвокатом клиенту, лишен ценности, если адвокат дает его только для того, чтобы угодить себе, служить своим личным интересам или под давлением извне.'),
#    ('Доверие и личная порядочность ', 'Доверие и Личная Целомудрие '),
#    ('Доверительные отношения между адвокатом и клиентом могут возникнуть лишь в случае отсутствия у последнего сомнений относительно порядочности, честности и добросовестности адвоката.',
#     'Отношения доверия могут существовать только в случае, если личная честь, честность и непорочность адвоката выше всякого сомнения.'),
#    ('Для адвоката эти традиционные ценности являются профессиональными обязательствами.',
#     'Для адвоката эти традиционные добродетели являются профессиональными обязанностями.'),
#    ('Конфиденциальность', 'Конфиденциальность'),
#    ('Сущность профессии адвоката заключается в том, что он получает от клиента сведения, которые тот не станет сообщать какому-либо другому лицу, а также другую информацию, которую ему следует сохранять в тайне.',
#     'Сущностью функции адвоката является то, что адвокат должен быть проинформирован своим клиентом о том, что клиент не рассказал бы другим, и что адвокат должен быть получателем другой информации на конфиденциальной основе.'),
#    ('Доверие к адвокату может возникать лишь при условии обязательного соблюдения им принципа конфиденциальности.',
#     'Без уверенности в конфиденциальности нет доверия.'),
#    ('Таким образом, конфиденциальность является первостепенным и фундаментальным правом и обязанностью адвоката.',
#     'Поэтому конфиденциальность является первичным и фундаментальным правом и обязанностью адвоката.'),
#    ('Данная обязанность адвоката сохранять конфиденциальность служит интересам отправления правосудия, а также интересам клиента, а следовательно подпадает под особую защиту государства.',
#     'Обязанность адвоката соблюдать конфиденциальность служит интересам правосудия, а также интересам клиента.'),
#    ('Адвокат должен соблюдать конфиденциальность всей информации, которая становится известна ему в процессе профессиональной деятельности.',
#     'Поэтому она имеет право на особую защиту со стороны государства.'),
#    ('На обязанность соблюдения конфиденциальности не распространяется действие срока давности.',
#     'Адвокат обязан уважать конфиденциальность всей информации, ставшей ему известной в ходе его профессиональной деятельности.'),
#    ('Адвокат обязан требовать соблюдения конфиденциальности от партнеров, помощников и от любых других лиц, принимающих участие в оказании услуг клиенту.',
#     'Обязанность по конфиденциальности не ограничивается по времени.'),
#    ('Соблюдение правил других объединений адвокатов.',
#     'Адвокат обязан требовать от своих коллег и персонала, а также всех, кто занимается оказанием профессиональных услуг по обязательству соблюдать ту же обязанность по конфиденциальности.'),
#    ('При осуществлении международной деятельности адвокат другого государства-члена должен руководствоваться правилами объединения адвокатов той страны союза, где он занимается профессиональной деятельностью.',
#     'Уважение к Правилам Других Адвокатских Палат и Обществ Практикуя пограничную деятельность, адвокат из другого государства-члена может обязан соблюдать профессиональные правила принимающего государства-члена.'),
#    ('Адвокаты обязаны предоставлять информацию о каких-либо правилах, которые могут повлиять на выполнение ими профессиональной деятельности.',
#     'Адвокаты имеют обязанность ознакомиться с правилами, которые повлияют на них при выполнении конкретной деятельности.'),
#    ('Организации – члены Совета адвокатских объединений и юридических обществ Европы обязаны депонировать свои кодексы поведения в секретариате Совета адвокатских объединений и юридических обществ Европы для того, чтобы любой адвокат мог получить копию данного кодекса в секретариате.',
#     'Членство организаций ССБЕ обязаны предоставить свои кодексы поведения в Секретариат ССБЕ, чтобы любой адвокат мог получить копию текущего кодекса из Секретариата.'),
#    ('Недопустимые виды деятельности', 'Несовместимые Занятия'),
#    ('В целях обеспечения независимости адвоката при выполнении им профессиональных обязанностей и в связи с тем, что он является одним из участников осуществления правосудия, некоторые виды деятельности признаются несовместимыми с его статусом.',
#     'Для выполнения своих функций с должной независимостью и в соответствии с своим долгом участвовать в осуществлении правосудия адвокат может быть запрещен заниматься некоторыми видами деятельности.'),
#    ('Адвокат, выступающий в государстве нахождения в роли защитника или участвующий от имени клиента в судебном разбирательстве, обязан действовать в соответствии с положением о недопустимых видах деятельности, существующим в государстве нахождения.',
#     'Адвокат, действующий в представительстве или защите клиента в судебных разбирательствах или перед любыми публичными органами в принимающем государстве-члене, должен соблюдать правила о несовместимых занятиях, как это применяется к адвокатам принимающего госуд'),
#    ('Преамбула.', 'Преамбула.'),
#    ('Принимая во внимание целесообразность некоторого уточнения и изменения законодательства о договорах, настоящим устанавливается следующее.',
#     'Учитывая, что целесообразно определить и внести изменения в некоторые части закона, касающиеся контрактов; настоящим утверждается следующее.'),
#    ('Предварительная глава 1.', 'Предварительно 1.'),
#    ('Краткое наименование.', 'Краткое название.'),
#    ('― Настоящий Акт может называться Индийским законом о договорах 1872 г.',
#     '― Данный Закон может называться «Индийский Контрактный Закон 1872 года».'),
#    ('Интерпретационная статья.', 'Интерпретационный пункт.'),
#    ('― В настоящем Законе следующие слова и выражения используются в перечисленных ниже смыслах, если иное не следует из контекста: (a) если одно лицо оповещает другое о своей готовности совершить или воздержаться от совершения какого-либо действия с целью получить согласие адресата приобрести право на такое действие или на воздержание от него, оно считается сделавшим предложение; (b) если лицо, которому сделано предложение, уведомляет того, кто его сделал, о своем согласии получить предложенное, предложение считается акцептованным.',
#     '― В данном Законе следующие слова и выражения используются в следующих значениях, если контекст не предполагает обратного: (a) Когда одно лицо выражает другому свою готовность что-либо сделать или воздержаться от совершения действий с целью получения согласия этого лица на такой акт или воздержание, говорят, что оно делает предложение; (b) Когда лицо, которому сделано предложение, выражает свое согласие на него, предложение считается принятым.'),
#    ('Предложение, будучи акцептованным, становится обязательством; (c) делающий предложение называется должником, а лицо, акцептующее предложение, называется кредитором; (d) если, действуя в соответствии с условием должника, кредитор, или любое другое лицо, сделал нечто или воздержался от действия, либо же делает нечто или воздерживается от действия, либо обязуется совершить или воздержаться от действия, то такое действие, воздержание или обязательство называется встречным удовлетворением по обязательству; (e) каждое обязательство, одно или несколько, в совокупности с предоставленным за них встречным удовлетворением образуют соглашение; (f) обязательства, каждое из которых составляет встречное удовлетворение друг друга полностью или в части, называются взаимными; (g) соглашение, не имеющее юридической силы, называется недействительным; (h) соглашение, имеющее юридическую силу, представляет собой договор; (i) соглашение, юридическая сила которого зависит от усмотрения одного или нескольких лиц, участвующих на одной его стороне, является оспоримым договором; (j) договор, имеющий юридическую силу, становится недействительным, если он перестает быть исполнимым.',
#     'Предложение, после принятия, становится обещанием; (c) Лицо, делающее предложение, называется обещающим, а лицо, принимающее предложение, - обещающим; (d) Если по желанию обещающего обещающее лицо или какое-либо другое лицо сделало что-либо, воздержалось от совершения действий, обещает что-либо сделать или воздержаться от действий, то такое действие, воздержание или обещание называется вознаграждением за обещание; (e) Каждое обещание и каждый набор обещаний, являющихся вознаграждением друг для друга, являются соглашением; (f) Обещания, которые являются вознаграждением или частью вознаграждения друг для друга, называются взаимными обещаниями; (g) Соглашение, не подлежащее исполнению по закону, считается недействительным; (h) Соглашение, которое подлежит исполнению по закону, является контрактом; (i) Соглашение, которое подлежит исполнению по закону по выбору одной или нескольких сторон, но не по выбору других сторон, является аннулируемым контрактом; (j) Контракт, который перестает быть исполнимым по закону, становится недействительным, когда прекращает быть исполнимым по закону.'),
#    ('Глава I. О сообщении, акцепте и отзыве предложений',
#     'Глава I. О коммуникации, принятии и отзыве предложений.'),
#    ('Сообщение, акцепт и отзыв предложений.',
#     'Коммуникация, принятие и отзыв предложений.'),
#    ('― Доведение предложений, акцептов предложений, а также отзыв предложений и акцептов, в зависимости от случая, считаются состоявшимися с совершением действия или бездействием стороны, предлагающей, акцептующей или отменяющей, которым она намеревается сообщить предложение, акцепт или отзыв или которое имеет эффект такого сообщения.',
#     '― Коммуникация предложений, принятие предложений и отзыв предложений и принятий считаются совершенными любыми действиями или бездействием лица, делающего предложение, принимающего или отзывающего его, которое имеет целью сообщить такое предложение, принятие или отзыв, или которое фактически сообщает это.'),
#    ('Когда сообщение считается состоявшимся.', 'Завершение коммуникации.'),
#    ('― Сообщение предложения считается состоявшимся в момент, когда оно стало известным лицу, которому оно сделано.',
#     '― Коммуникация предложения завершается, когда человек, которому оно сделано, узнает об этом.'),
#    ('Сообщение акцепта считается состоявшимся: в отношении лица, предложение которого акцептуется, — с того момента, после которого акцептант не в силах отменить акцепт; в отношении акцептанта — когда акцепт становится известным сделавшему предложение.',
#     'Коммуникация принятия завершается: по отношению к предлагающему, когда оно отправлено к нему по пути передачи так, чтобы находиться вне досягаемости принимающего; по отношению к принимающему, когда предложающий об этом узнает.'),
#    ('Сообщение об отзыве считается состоявшимся: в отношении лица, которое направило отзыв, — с того момента, когда он, будучи направлен надлежащим образом, уже не может быть отменен лицом, направившим его; в отношении лица, которому направлен отзыв, — с момента, когда ему стало известно о нем.',
#     'Коммуникация отзыва считается завершенной: по отношению к лицу, сделавшему его, когда он отправлен к лицу, которому он адресован, по пути передачи, так чтобы находиться вне досягаемости лица, сделавшего его; по отношению к лицу, которому он адресован, когда оно становится известно ему.')]}}

# %%
file_path = 'reference_candidate.json'

# Save the dictionary as a .json file
with open(file_path, 'w') as json_file:
    json.dump(reference_candidate_dict, json_file, indent=4)

print(f"Dictionary saved as '{file_path}'")
# Out:
# Dictionary saved as 'reference_candidate.json'
